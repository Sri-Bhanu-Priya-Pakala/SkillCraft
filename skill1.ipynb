# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
#load the dataset
data=pd.read_csv(r"C:\Users\USER\Downloads\IndPopAge0-6.2011.csv")
print(data)
# Out:
#     State or UT code                  State or UT     Total      Male  \
# 0                  1            Jammu and Kashmir   2008670   1080662
# 1                  2             Himachal Pradesh    763864    400681
# 2                  3                       Punjab   2941570   1593262
# 3                  4                   Chandigarh    117953     63187
# 4                  5                  Uttarakhand   1328844    704769
# 5                  6                      Haryana   3297724   1802047
# 6                  7                        Delhi   1970510   1055735
# 7                  8                    Rajasthan  10504916   5580212
# 8                  9                Uttar Pradesh  29728235  15653175
# 9                 10                        Bihar  18582229   9615280
# 10                11                       Sikkim     61077     31418
# 11                12            Arunachal Pradesh    202759    103430
# ...

# %%
# Sum up male and female population across all states
total_male = df['Male'].sum()
total_female = df['Female'].sum()

# Create summary DataFrame
data = pd.DataFrame({
    'Gender': ['Male', 'Female'],
    'Population': [total_male, total_female]
})

# bar plot
sns.barplot(data=data, x='Gender', y='Population', palette='pastel')
plt.title('Total Male and Female Population in India (2011)')
plt.ylabel('Population Count')
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_1592\162529333.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=data, x='Gender', y='Population', palette='pastel')

# %%
plt.figure(figsize=(9, 6))
sns.histplot(data=df, x='Total', bins=10, kde=True, color='thistle', edgecolor='black')
plt.title('Population Distribution')
plt.xlabel('Population')
plt.ylabel('Number of States')
plt.show()
